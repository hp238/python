# %%
import kwikfile as kf
import numpy as np
import imp
# %matplotlib inline
import matplotlib.pyplot as plt
from klusta.kwik import KwikModel

kwik_path='/home/harison/UFPE/data/g01.kwik'

file = kf.KwikFile(kpath=kwik_path)
model = KwikModel(kwik_path)
# Out:
# Created class on = /home/harison/UFPE/data/g01.kwik !

# %%
clu=file.clusters(group_name='good')
print (clu)
clu=file.clusters(group_name='noise')
print(clu)
# Out:
# [6, 20, 36, 45, 52, 56, 67, 71, 91, 94, 96, 99, 103, 104, 106, 107, 110, 111, 112, 116, 118, 119, 120, 121, 122]
# [0, 2, 3, 10, 11, 16, 21, 29, 30, 40, 44, 50, 55, 61, 62, 73, 78, 83, 87, 88, 92]

# %%
all = file.all_clusters()
print(all)
# Out:
# [0, 2, 3, 4, 5, 6, 10, 11, 14, 15, 16, 20, 21, 22, 24, 27, 29, 30, 31, 32, 36, 38, 40, 41, 44, 45, 47, 50, 51, 52, 55, 56, 57, 58, 60, 61, 62, 66, 67, 70, 71, 72, 73, 78, 83, 84, 85, 87, 88, 89, 91, 92, 94, 96, 99, 103, 104, 106, 107, 110, 111, 112, 116, 118, 119, 120, 121, 122]

# %%
model.all_waveforms.shape
# Out:
# (1172577, 32, 10)

# %%
w =  model.all_waveforms
print(model.cluster_ids)
# Out:
# [  0   2   3   4   5   6  10  11  14  15  16  20  21  22  24  27  29  30
#   31  32  36  38  40  41  44  45  47  50  51  52  55  56  57  58  60  61
#   62  66  67  70  71  72  73  78  83  84  85  87  88  89  91  92  94  96
#   99 103 104 106 107 110 111 112 116 118 119 120 121 122]

# %%
cluster_id = 20
clusters = model.spike_clusters
idx=np.argwhere (clusters==cluster_id)
#print(idx)
w=model.all_waveforms[idx]

spike_id = np.arange(w.shape[0])
np.random.shuffle(spike_id)
spike_id = spike_id[0:100]
#fig=plt.figure()
for ch in range(0,10):
    #print(ch)
    fig=plt.figure()
    print(model.channel_positions[ch,0])
    print(model.channel_positions[ch,1])
    #print(model.channel_positions[j,0])
    #py = model.channel_positions[:,1]
    #print(py[j]*4)
    for i in spike_id:
        plt.plot(0.05*w[i,:,ch],color='cyan')
        plt.show
    plt.plot(0.05*np.mean(w[:,:,ch],0),"--",color="black",linewidth=3,alpha=0.3)
# Out:
# 0.0
# 0.0
# 32.0
# 20.0
# 2.5
# 40.0
# 29.5
# 60.0
# 5.0
# 80.0
# 27.0
# 100.0
# 7.5
# 120.0
# 24.5
# 140.0
# 10.0
# 160.0
# 22.0
# 180.0

# %%
print(w.shape)
print(w.shape[1])
print(w.shape[2])
# Out:
# (1172577, 32, 10)
# 32
# 10

# %%
m = np.mean(w[:,:,:],0)

m = m.T
m.shape
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-8-4068a4c57abd> in <module>()
#       1
# ----> 2 m = np.mean(w[:,:,:],0)
#       3
#       4 m = m.T
#       5 m.shape
#
# ~/miniconda3/envs/phy/lib/python3.5/site-packages/klusta/traces/waveform.py in __getitem__(self, item)
#     382
#     383     def __getitem__(self, item):
# --> 384         times = self._spike_samples[item]
#     385         return self._waveforms[times]
#     386
#
# IndexError: too many indices for array

# %%
for ch in range(0,10):
    #fig=plt.figure()
    plt.plot(m[ch,:])
    plt.show

# %%
med = np.zeros((10,32))
clusters = model.spike_clusters
idx=np.argwhere (clusters==cluster_id)
w=model.all_waveforms[idx]
for ch in range (0,num_channels):
        med[ch,:]+=np.mean(w[:,:,ch],0)

# %%
cluster_id=20
idx=np.argwhere (clusters==cluster_id)
#print(idx)
w=model.all_waveforms[idx]

spike_id = np.arange(w.shape[0])
np.random.shuffle(spike_id)
spike_id = spike_id[0:100]
#fig=plt.figure()
for ch in range(0,10):
    #print(ch)
    fig=plt.figure()
    print("x="+model.channel_positions[j,0])
    print("y="+model.channel_positions[j,1])
    #py = model.channel_positions[:,1]
    #print(py[j]*4)
    for i in spike_id:
        plt.plot(0.05*w[i,:,ch],color='cyan')
        plt.show
    plt.plot(0.05*np.mean(w[:,:,ch],0))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-beac882b80ac> in <module>()
#       1 cluster_id=20
# ----> 2 idx=np.argwhere (clusters==cluster_id)
#       3 #print(idx)
#       4 w=model.all_waveforms[idx]
#       5
#
# NameError: name 'clusters' is not defined

# %%
med = np.zeros((10,32))
group_name='good'
for cluster_id in file.clusters(group_name=group_name):
    clusters = model.spike_clusters
    idx=np.argwhere (clusters==cluster_id)
    w=model.all_waveforms[idx]
    num_channels = w.shape[2]
    print(cluster_id)
    for ch in range (0,num_channels):
        med[ch,:]+=np.mean(w[:,:,ch],0)
# Out:
# 6
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-85863245e8c1> in <module>()
#       4     clusters = model.spike_clusters
#       5     idx=np.argwhere (clusters==cluster_id)
# ----> 6     w=model.all_waveforms[idx]
#       7     num_channels = w.shape[2]
#       8     print(cluster_id)
#
# ~/miniconda3/envs/phy/lib/python3.5/site-packages/klusta/traces/waveform.py in __getitem__(self, item)
#     383     def __getitem__(self, item):
#     384         times = self._spike_samples[item]
# --> 385         return self._waveforms[times]
#     386
#     387     def __len__(self):
#
# ~/miniconda3/envs/phy/lib/python3.5/site-packages/klusta/traces/waveform.py in __getitem__(self, item)
#     359         for i, time in enumerate(spikes):
#     360             try:
# --> 361                 waveforms[i, ...] = self._load_at(time)
# ...

# %%
for ch in range(0,10):
    #fig=plt.figure()
    plt.plot(med[ch,:])
    plt.show

# %%
for i in range (0,10):
    med[ch,:]/=len(file.clusters(group_name='good'))

# %%
for ch in range(0,10):
    #fig=plt.figure()
    plt.plot(med[ch,:])
    plt.show

# %%
med = np.zeros((len(file.clusters(group_name='good')),10,32))
i=0              
for cluster_id in file.clusters(group_name='good'):
    clusters = model.spike_clusters
    idx=np.argwhere (clusters==cluster_id)
    w=model.all_waveforms[idx]
    num_channels = w.shape[2]
    print(cluster_id)
    #for ch in range (0,num_channels):
    med[i,:,:]+=np.mean(w[i,:,:],0)
    i+=1
# Out:
# 6
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-20-779c0f472e5d> in <module>()
#       8     print(cluster_id)
#       9     #for ch in range (0,num_channels):
# ---> 10     med[i,:,:]+=np.mean(w[i,:,:],0)
#      11     i+=1
#
# ValueError: operands could not be broadcast together with shapes (10,32) (10,) (10,32)

# %%
med2=np.mean(w[:,:,:],0)
med2=med2.T
med2.shape
for ch in range(0,10):
    #fig=plt.figure()
    plt.plot(med2[ch,:])
    plt.show

# %%
cluster_id=2
med2=np.mean(w[:,:,:],0)
med2=med2.T
med2.shape
for ch in range(0,10):
    #fig=plt.figure()
    plt.plot(med2[ch,:])
    plt.show

# %%
print(file.list_of_groups)
# Out:
# <bound method KwikFile.list_of_groups of <kwikfile.KwikFile object at 0x7f42b8417da0>>

# %%
groups=file.list_of_groups()
print (groups)
# Out:
# ['noise', 'good', 'mua']
